# %% [markdown]
# ## 📘This project performs web scraping on e-commerce Egypt website (**Noon**) to search for smartwatches. It collects key product details such as:
#
# ### It collects key product details such as:
# - Product Name
# - Price
# - Discount
# - Rating
# - Product Link
#
# ### Websites included:
# - Jumia Egypt
#
# ### The scraped data is exported to a CSV file saved in your current working directory.
#
# ---

# %% [markdown]
# ### 📦**Import Required Libraries**

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# This will auto-download the correct driver version
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import time
import pandas as pd

# %% [markdown]
# ### ⚙️**Configure Selenium WebDriver**

# %%
options = Options()
options.add_argument("--start-maximized")

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
driver.get("https://www.noon.com/egypt-en/search/?q=smart%20watches")

# Wait for page to load (adjust time if needed)
time.sleep(5)

# %% [markdown]
# ### 🔍**Locate Products on the Page**

# %%
products = driver.find_elements(By.CSS_SELECTOR, 'div.ProductBoxLinkHandler_linkWrapper__b0qZ9')  # this may need to be updated
print(f"Found {len(products)} products on the page.")
# Out:
# Found 50 products on the page.

# %% [markdown]
# ### **📋 Extracting Product Details**
# #### Extracts product details (name, price, rating, discount, and link) from the scraped product list and stores them in a structured list.

# %%
from selenium.webdriver.common.by import By

product_details = []

for product in products:
    try:
        name = product.find_element(By.CSS_SELECTOR,'h2.ProductDetailsSection_title__JorAV').text
    except:
        name = 'No Name found'

    try:
        price = product.find_element(By.CSS_SELECTOR,'div.Price_sellingPrice__HFKZf').text
    except:
        price = 'No Price found'

    try:
        link = product.find_element(By.TAG_NAME, 'a').get_attribute('href')
    except:
        link = 'No Link found'

    try:
        discount=product.find_element(By.CSS_SELECTOR,'div.Price_preReductionRow__yBUIC').text
    except:
        discount= "No Discount found"
    try:
        rate=product.find_element(By.CSS_SELECTOR,'div.RatingPreviewStar_textCtr__sfsJG').text
    except:
        discount= "No Rating found"   

    product_details.append({
        'Website': 'NOON',
        'PRODUCT NAME': name,
        'PRODUCT PRICE': price,
        'PRODUCT DISCOUNT':discount,
        'PRODUCT RATE':rate,
        'PRODUCT LINK': link
    })

print(f"Extracted {len(product_details)} products.")
# Out:
# Extracted 50 products.

# %% [markdown]
# ### **📢 Preview Scraped Products**

# %%
products = driver.find_elements(By.CSS_SELECTOR, 'div.ProductBoxLinkHandler_linkWrapper__b0qZ9')

# %%
# 📋 Viewing the first 5 products
for i, product in enumerate(product_details[:5], 1):   
    print(f"\n----- Product-no. {i} -----")
    for key, value in product.items():
        print(f"{key}: {value}")
# Out:
# ----- Product-no. 1 -----
# Website: NOON
# PRODUCT NAME: Amazfit Pop 3R Smart Watch With 1.43" (3.6 Cm) HD AMOLED Display, BT Calling And AI Voice Assistance Black
# PRODUCT PRICE: EGP
# 2,174
# PRODUCT DISCOUNT: 2,430
# 10% OFF
# PRODUCT RATE: 4.3
# PRODUCT LINK: https://www.noon.com/egypt-en/pop-3r-smart-watch-with-1-43-3-6-cm-hd-amoled-display-bt-calling-and-ai-voice-assistance-black/N70062236V/p/?o=bc5974e8d1f4b4db
#
# ----- Product-no. 2 -----
# Website: NOON
# PRODUCT NAME: T500 Bluetooth Full Touch Call Smartwatch With Replaceable Strap Black
# PRODUCT PRICE: EGP
# 350
# PRODUCT DISCOUNT: 600
# 41% OFF
# PRODUCT RATE: 3.1
# PRODUCT LINK: https://www.noon.com/egypt-en/bluetooth-full-touch-call-smartwatch-with-replaceable-strap-black/N43241184A/p/?o=e73f511b67286a9f
#
# ----- Product-no. 3 -----
# Website: NOON
# PRODUCT NAME: Samsung Fit 3 Smartwatch Amoled Display, Accelerometer, Barometer, Gyro Sensor, Optical Heart Rate Sensor, Light Sensor Gray
# PRODUCT PRICE: EGP
# ...

# %%
# 📋 Viewing the first 5 products
for i, product in enumerate(products_details[:5], 1):   
    print(f"\n----- Product-no. {i} -----")
    for key, value in product.items():
        print(f"{key}: {value}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 2
#       1 # 📋 Viewing the first 5 products
# ----> 2 for i, product in enumerate(products_details[:5], 1):
#       3     print(f"\n----- Product-no. {i} -----")
#       4     for key, value in product.items():
#
# NameError: name 'products_details' is not defined

# %% [markdown]
# ### **💾Export to CSV**

# %%
import pandas as pd

# Convert to DataFrame
df = pd.DataFrame(product_details)

# Export to CSV
df.to_csv('noon_smart_watches.csv', index=False, encoding='utf-8-sig')

print("✅ Data successfully exported to 'noon_smart_watches.csv'. The file is saved in your working directory.")
# Out:
# ✅ Data successfully exported to 'noon_smart_watches.csv'. The file is saved in your working directory.

# %% [markdown]
# # ______________________________________________________________________________________
